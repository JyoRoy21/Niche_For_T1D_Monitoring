# %%
pip install scSpectra
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# packages
import scanpy as sc
import scanpy.external as sce
import anndata as anndata
#import diffxpy.api as de
from anndata import AnnData
import time
import os
import numpy as np
import seaborn as sns
import pandas as pd
import re
import h5py
import scipy
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as patches
import matplotlib.colors as colors
import matplotlib.font_manager
import glob
from collections import OrderedDict
from scipy.sparse import csr_matrix
from scanpy.external.pp import magic
from scipy.stats import zscore
import scipy.cluster.hierarchy as hc
from statistics import median
import math
from typing import Union

import numpy.matlib

import numpy as np
import json
import scanpy as sc
from collections import OrderedDict
import scipy
import pandas as pd
import matplotlib.pyplot as plt

#spectra imports
import Spectra as spc
from Spectra import Spectra_util as spc_tl
from Spectra import K_est as kst
from Spectra import default_gene_sets
import os

# %%
os.getcwd()
# Out:
# '/Users/jyotirmoyroy/Desktop/T1S_ImmunometabolismPaper/SingleCellRNASeq'

# %%
# load the default gene set dictionary from the Spectra paper:
annotations = spc.default_gene_sets.load()

# %%
pip install cytopus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygraphviz as pgv
print(pgv.__version__)
# Out:
# 2.0beta0.dev0

# %%
#pyvis is required for plotting interactive graphs
# !pip install pyvis

# %%
import cytopus as cp
import IPython

# %%
G = cp.KnowledgeBase()
# Out:
# KnowledgeBase object containing 92 cell types and 201 cellular processes

# %%
pip install mygene
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mygene
import pandas as pd
import contextlib
import io

# Initialize mygene
mg = mygene.MyGeneInfo()

def convert_genes_to_mouse(human_genes):
    # Convert all gene symbols to uppercase for consistency
    human_genes = [gene.upper() for gene in human_genes]

    # Suppress mygene output during the query
    with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()):
        # Query MyGene.info for mouse orthologs
        query = mg.querymany(
            human_genes, 
            scopes="symbol", 
            fields="symbol,entrezgene,ensembl.gene", 
            species="mouse", 
            as_dataframe=True
        )
    missing_genes = []
    # Extract mapped mouse genes
    mapped_genes = []
    for _, row in query.iterrows():
        if pd.notna(row['symbol']) and pd.notna(row['entrezgene']):  # If the gene was found
            mapped_genes.append(row['symbol'])
        else:  # If the gene was not found
            missing_gene = row.name  # The index contains the original query term
            missing_genes.append(missing_gene)


    # Manual mappings for genes that were not found
    manual_mappings = {
        'ZADH2': 'Zadh2',
        'ADH1A': 'Adh1',
        'PNPLA4': 'Pnpla4',
        'ADH1B': 'Adh1',
        'ADH1C': 'Adh1',
        'IFNA21': 'Ifna',
        'IFNA8': 'Ifna',
        'CASP10': 'Casp10',
        'IFNA17': 'Ifna',
        'DDX58': 'Ddx58',
        'IFNW1': 'Ifnw1',
        'MYL5': 'Myl5',
        'MT1X': 'Mt1',
        'TP53I3': 'Trp53i3',
        'MT2A': 'Mt2',
        'C3ORF52': 'C3orf52',
        'TP63': 'Trp63',
        'TP53': 'Trp53',
        'H2AW': 'H2aw',
        'H1-2': 'H1f2',
        'ZNF365': 'Zfp365',
        'RAB7A': 'Rab7',
        'MAP1LC3C': 'Map1lc3c',
        'ARNTL': 'Arntl',
        'KIF4A': 'Kif4a',
        'SGO2': 'Sgo2',
        'IRGM': 'Irgm',
        'SUPT5H': 'Supt5h',
        'LACRT': 'Lacrt',
        'SLCO1A2': 'Slco1a2',
        'SULT1A2': 'Sult1a2',
        'MMP1': 'Mmp1',
        'CCL16': 'Ccl16',
        'CXCL6': 'Cxcl6',
        'TNFRSF10C': 'Tnfrsf10c',
        'KITLG': 'Kitlg',
        'BCL2A1': 'Bcl2a1',
        'ICOSLG': 'Icoslg',
        'FTL': 'Ftl',
        'TF': 'Tf',
        'MAN1A1': 'Man1a1',
        'ALG10': 'Alg10',
        'CD59': 'Cd59',
        'ENOSF1': 'Enosf1',
        'SCD': 'Scd',
        'LILRB5': 'Lilrb5',
        'CCL18': 'Ccl18',
        'C1S': 'C1s',
        'C1R': 'C1r',
        'C5': 'C5',
        'CKMT1B': 'Ckmt1b',
        'H2BC19P': 'H2bc19',
        'H1-4': 'H1f4',
        'H2BC17': 'H2bc17',
        'H2BC10': 'H2bc10',
        'H3-2': 'H3f2',
        'H4C13': 'H4c13',
        'H2AC16': 'H2ac16',
        'H2BP2': 'H2bp2',
        'H2BP1': 'H2bp1',
        'H2AZP3': 'H2azp3',
        'H2BU1': 'H2bu1',
        'C1ORF68': 'C1orf68',
        'HBD': 'Hbd',
        'C10ORF90': 'C10orf90',
        'OR10H3': 'Olfr123',
        'SIGLEC5': 'Siglec5',
        'ZNF90': 'Zfp90',
        'ZNF493': 'Zfp493',
        'STH': 'Sth',
        'ZNF557': 'Zfp557',
        'REG1A': 'Reg1a',
        'IL4R': 'Il4r',
        'CA12': 'Ca12',
        'GPI': 'Gpi',
        'MT1E': 'Mt1',
        'ZNF292': 'Zfp292',
        'GABARAPL3': 'Gabarapl3',
        'GBA': 'Gba',
        'MAP1LC3B2': 'Map1lc3b2',
        'TMSB4XP8': 'Tmsb4x',
        'FGF19': 'Fgf19',
        'TMSB4Y': 'Tmsb4y',
        'INS': 'Ins',
        'IFI6': 'Ifi6',
        'OASL': 'Oasl',
        'ZNF697': 'Zfp697',
        'ZBED2': 'Zbed2',
        'SIAH1': 'Siah1',
        'KIAA1549L': 'Kiaa1549l',
        'SI': 'Si',
        'IL26': 'Il26',
        'GBA': 'Gba',
        'CD8B': 'Cd8b',
        'ATP6V0E1': 'Atp6v0e1',
        'CHMP4A': 'Chmp4a',
        'CD244': 'Cd244',
        'TTC37': 'Ttc37',
        'GLUD2': 'Glud2',
        'STX4': 'Stx4',
        'CHST6': 'Chst6',
        'CYP2C18': 'Cyp2c18',
        'PRB3': 'Prb3',
        'LYZ': 'Lyz',
        'SERPINB3': 'Serpinb3',
        'S100P': 'S100p',
        'CA2': 'Ca2',
        'CST1': 'Cst1',
        'CSTA': 'Csta',
        'SH2D1B': 'Sh2d1b',
        'YAE1': 'Yae1',
        'LDHAL6A': 'Ldhal6a',
        'NLRP9': 'Nlrp9b',
        'GSDMB': 'Gsdmb',
        'G6PD': 'G6pd',
        'PRAMEF6': 'Pramef6',
        'RNF175': 'Rnf175',
        'RNF103-CHMP3': 'Chmp3',
        'CAMLG': 'Camlg',
        'GPI': 'Gpi',
        'ABCF2-H2BE1': 'H2be1',
        'SLC9A3R1': 'Slc9a3r1',
        'CYP51A1': 'Cyp51a1',
        'DEFB123': 'Defb123',
        'C17ORF78': 'C17orf78',
        'PTTG3P': 'Pttg3p',
        'TAF1L': 'Taf1l',
        'DDX53': 'Ddx53',
        'APOBEC3B': 'Apobec3b',
        'TEPP': 'Tepp',
        'ALPP': 'Alpp',
        'CLC': 'Clc',
        'GK3P': 'Gk3p',
        'LGALS13': 'Lgals13',
        'ALPG': 'Alpg',
        'IL6R': 'Il6r',
        'IL11RA': 'Il11ra',
        'CSH1': 'Csh1',
        'CSH2': 'Csh2',
        'GH2': 'Gh2',
        'GH1': 'Gh1',
        'ZNRD1': 'Znrd1',
        'NT5C3A': 'Nt5c3a',
        'ZNF707': 'Zfp707',
        'SUPT4H1': 'Supt4h1',
        'BOLA2B': 'Bola2b',
        'TP53INP1': 'Trp53inp1',
        'STX5': 'Stx5',
        'UGT2B17': 'Ugt2b17',
        'ABCB1': 'Abcb1',
        'ACAA1': 'Acaa1',
        'PHB': 'Phb',
        'TP53INP2': 'Trp53inp2',
        'TRIM34': 'Trim34',
        'TRIM22': 'Trim22',
        'ST6GALNAC2': 'St6galnac2',
        'SERTAD4-AS1': 'Sertad4-as1',
        'TMEM178A': 'Tmem178a',
        'CAPN14': 'Capn14',
        'HSPB11': 'Hspb11',
        'CA6': 'Ca6',
        'CD1D': 'Cd1d',
        'CA4': 'Ca4',
        'CCDC58': 'Ccdc58',
        'CYP4A22': 'Cyp4a22',
        'SERPINA1': 'Serpina1',
        'GZMH': 'Gzmh',
        'FGFBP2': 'Fgfbp2',
        'GNLY': 'Gnly',
        'CHIA': 'Chia',
        'CENPJ': 'Cenpj',
        'C4ORF33': 'C4orf33',
        'TSTA3': 'Tsta3',
        'RNASE2': 'Rnase2',
        'GSTT2B': 'Gstt2b',
        'LGALS9B': 'Lgals9b',
        'FLT3LG': 'Flt3lg',
        'SERPINB6': 'Serpinb6',
        'EFCAB1': 'Efcab1',
        'ZNF124': 'Zfp124',
        'BVES': 'Bves',
        'C12ORF49': 'C12orf49',
        'ZNF623': 'Zfp623',
        'KIAA0513': 'Kiaa0513',
        'ZNF770': 'Zfp770',
        'OXCT2': 'Oxct2',
        'CTSV': 'Ctsv',
        'AKR7A2': 'Akr7a2',
        'HLA-C': 'H2-L',
        'HLA-A': 'H2-K',
        'HLA-B': 'H2-D',
        'ANKH': 'Ankh',
        'H1-0': 'H1f0',
        'BCL2L2-PABPN1': 'Pabpn1',
        'PEA15': 'Pea15',
        'PXDNL': 'Pxdnl',
        'CES2': 'Ces2',
        'ZNF641': 'Zfp641',
        'CD1C': 'Cd1c',
        'ZNF398': 'Zfp398',
        'VNN2': 'Vnn2',
        'CYP2C8': 'Cyp2c8',
        'CYP2A13': 'Cyp2a13',
        'CYP2C9': 'Cyp2c29',
        'CYP2B6': 'Cyp2b6',
        'ALOX15B': 'Alox8',
        'ZNF516': 'Zfp516',
        'STATH': 'Stath',
        'TXN': 'Txn',
        'S100A12': 'S100a12',
        'S100A7': 'S100a7',
        'DEFB4B': 'Defb4b',
        'GALNT8': 'Galnt8',
        'ARMC4': 'Armc4',
        'MIR1915HG': 'Mir1915hg',
        'ZNF467': 'Zfp467',
        'KLK3': 'Klk3',
        'C19ORF38': 'C19orf38',
        'C1ORF229': 'C1orf229',
        'CES1': 'Ces1',
        'ZNF579': 'Zfp579',
        'NKX2-8': 'Nkx2-8',
        'CXCL6': 'Cxcl6',
        'MT1M': 'Mt1',
        'MT1G': 'Mt1',
        'GBP1': 'Gbp1',
        'IL32': 'Il32',
        'OAS1': 'Oas1',
        'FCGR3A': 'Fcgr3a',
        'BTN3A2': 'Btn3a2',
        'REN': 'Ren',
        'SCD5': 'Scd5',
        'NCR3': 'Ncr3',
        'C3ORF18': 'C3orf18',
        'CYP4A11': 'Cyp4a12a',
        'CYP3A4': 'Cyp3a11',
        'CYP2A6': 'Cyp2a5',
        'AKR1C4': 'Akr1c18',
        'CYP4F2': 'Cyp4f14',
        'CA13': 'Car13',
        'NLRP1': 'Nlrp1a',
        'PYDC1': 'Pydc3',
        'NAIP': 'Naip1',
        'ADH6': 'Adh6b',
        'CD58': 'Cd58',  # CD58 is conserved in mice
    'FCER2': 'Fcer2a',  # Mouse ortholog of human FCER2
    'CD24': 'Cd24a',  # Mouse ortholog of human CD24
    'TM4SF18': 'Tm4sf18',  # Mouse ortholog of human TM4SF18
    'CCL21': 'Ccl21',  # Mouse ortholog of human CCL21
    'TNFRSF10A': 'Tnfrsf10a',  # Mouse ortholog of human TNFRSF10A
    'LILRB1': 'Pirb',  # Mouse ortholog of human LILRB1
    'CR1': 'Crry',  # Mouse ortholog of human CR1 (complement receptor 1)
    'ZNF385D': 'Zfp385d',  # Mouse ortholog of human ZNF385D
    'CYP3A5': 'Cyp3a11',  # Mouse ortholog of human CYP3A5
    'KIAA1217': 'Kiaa1217',  # Mouse ortholog of human KIAA1217
    'KLRF1': 'Klrf1',  # Mouse ortholog of human KLRF1
    'CLEC4C': 'Clec4c',  # Mouse ortholog of human CLEC4C
    'LILRB4': 'Pirb',  # Mouse ortholog of human LILRB4
    'LILRA4': 'Pira',  # Mouse ortholog of human LILRA4
    'IGHA1': 'Igha',  # Mouse ortholog of human IGHA1
    'IGHA2': 'Igha',  # Mouse ortholog of human IGHA2
    'IGHG1': 'Ighg1',  # Mouse ortholog of human IGHG1
    'IGHG2': 'Ighg2',  # Mouse ortholog of human IGHG2
    'IGHG4': 'Ighg4',  # Mouse ortholog of human IGHG4
    'CEACAM8': 'Ceacam8',  # Mouse ortholog of human CEACAM8
    'FCGR3B': 'Fcgr3',  # Mouse ortholog of human FCGR3B
    'AZU1': 'Azurocidin',  # Mouse ortholog of human AZU1
    'LILRA2': 'Pira',  # Mouse ortholog of human LILRA2
    'CLEC4A': 'Clec4a',  # Mouse ortholog of human CLEC4A
    'NCR2': 'Ncr2',  # Mouse ortholog of human NCR2
    'FCGR1B': 'Fcgr1',  # Mouse ortholog of human FCGR1B
    'FCGR2A': 'Fcgr2a',  # Mouse ortholog of human FCGR2A
    'FCGR1A': 'Fcgr1a',  # Mouse ortholog of human FCGR1A
    'CD1A': 'Cd1d1',  # Mouse ortholog of human CD1A
    'CD209': 'Cd209a',  # Mouse ortholog of human CD209
    'TRDC': 'Trdc',  # Mouse ortholog of human TRDC
    'FCN3': 'Fcn3',  # Mouse ortholog of human FCN3
    'TRBC1': 'Trbc1',  # Mouse ortholog of human TRBC1
    'TRAC': 'Trac',  # Mouse ortholog of human TRAC
    }
    # Add manual mappings for missing genes
    unresolved_genes = []
    # Add manual mappings to the mapped_genes list
    for human_gene in missing_genes:
        if human_gene in manual_mappings:
            mapped_genes.append(manual_mappings[human_gene])
        else:
            unresolved_genes.append(human_gene)

    # Report unresolved genes (genes still missing after manual mappings)
    if unresolved_genes:
        print(f"Warning: No match found for {unresolved_genes}")
    # Ensure the final list is unique
    mapped_genes = list(set(mapped_genes))

    return mapped_genes

human_genes = ["TP53", "MYC", "GATA3", "CD8A"]
mouse_genes = convert_genes_to_mouse(human_genes)
print(mouse_genes)
# Out:
# ['Myc', 'Gata3', 'Trp53', 'Cd8a']

# %%
celltype_of_interest = ['Mac']  
global_celltypes = ['all-cells','leukocyte','Mac']

# %%
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents =True,
                        child_depth=1,parent_depth=1)

# %%
conversion_dict = {
 'Mac':'Mac'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
# Convert genes for cell type processes
for celltype, processes_dict in G.celltype_process_dict.items():
    for process, genes in processes_dict.items():
        G.celltype_process_dict[celltype][process] = convert_genes_to_mouse(genes)

# %%
G.celltype_process_dict.items()
# Out:
# dict_items([('Mac', {'M_IL17A_response': ['Il1b', 'Il12a', 'Ifng', 'Cxcl3', 'Ccl3', 'Csf2', 'Il9', 'Il12b'], 'M_mac_CSF1_response': ['Pltp', 'Slc47a1', 'Vat1', 'Hadh', 'Pebp1', 'Scd', 'Slc38a6', 'Vsig4', 'Rragd', 'Zfyve26', 'Sqle', 'Acp5', 'Acat2', 'Cep55', 'Rgl1', 'Spp1', 'Itgb5', 'Idh1', 'Cyb5a', 'Dhcr7', 'Dhcr24', 'A2m', 'C3ar1', 'Enosf1', 'Nr1h3', 'Ptprm', 'Plpp3', 'Ctsk', 'Lgmn', 'Mgll', 'Lilrb5', 'Gnpda1', 'Jakmip2', 'Plxna1', 'Snx24', 'Npc1', 'Frmd4a', 'Dennd2d', 'Acot13', 'Tspan4', 'Slc7a8', 'Cd59', 'Aldh7a1', 'Apoe', 'C1qb', 'Ccl2', 'Nrp1', 'Etv5', 'Fuca1', 'Gpr137b', 'Optn', 'Colec12', 'Marco', 'Mapk13', 'Hsd17b14', 'Dram1', 'Rnase1', 'Rad51ap1', 'Maf', 'Melk', 'Tyms', 'Ctsl', 'Rab3il1', 'Plau', 'Apoc1', 'Bcat1', 'Hamp', 'Pla2g15', 'Msr1', 'Mmp9', 'Qprt', 'Pparg', 'Rarres1', 'Lima1', 'Dab2', 'Top2a', 'Slc39a8', 'Ecm1', 'Ccnd1', 'Slc2a5', 'Acp2', 'Fasn', 'Gpnmb', 'Epas1', 'Ms4a4a', 'Adamdec1', 'Npl', 'Hacd3'], 'M_angiogenic-effectors': ['Vegfc', 'Plau', 'Angpt2', 'Pdgfb', 'J
# ...

# %%
#convert celltype labels back to celltypes in data
Spectra_dict_Mac = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict_Mac[conversion_dict_inv[i]] = v

# %%
Spectra_dict_Mac.keys()
# Out:
# dict_keys(['Mac', 'global'])

# %%
Spectra_dict_Mac['Mac'].keys()
# Out:
# dict_keys(['M_IL17A_response', 'M_mac_CSF1_response', 'M_angiogenic-effectors'])

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict_Mac.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict_Mac,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict_Mac.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict_Mac.json'
f = open(jpath, 'r')
Spectra_dict_Mac = json.loads(f.read())

# %%
# Load the .h5ad file
T1D_Timepoints = sc.read("/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/T1D_Timepoints_scr.h5ad")

# %%
# Subset for CD8TCells (keeping only 'CD8 exhausted effector-like' and 'CD8 memory')
# Filter for 'CD8 exhausted effector-like' and 'CD8 memory' in 'CellSubType'
Mac = T1D_Timepoints[T1D_Timepoints.obs['CellSubType'].isin(['Macrophage'])].copy()

# Check the number of cells in each subset
print("Mac", Mac.shape)
# Out:
# Mac (1250, 6225)

# %%
list(set(Mac.obs['CellSubType']))
# Out:
# ['Macrophage']

# %%
# To view gene names in the AnnData object
gene_names = Mac.var_names  # For AnnData format, this holds the gene names
print(gene_names)
# Out:
# Index(['Lypla1', 'Tcea1', 'Atp6v1h', 'Rb1cc1', 'Vcpip1', 'Sgk3', 'Cops5',
#        'Cspp1', 'Arfgef1', 'Lactb2',
#        ...
#        'mt-Co1', 'mt-Co2', 'mt-Atp8', 'mt-Atp6', 'mt-Co3', 'mt-Nd3', 'mt-Nd4l',
#        'mt-Nd5', 'mt-Nd6', 'mt-Cytb'],
#       dtype='object', length=6225)

# %%
print(Spectra_dict_Mac)
# Out:
# {'Mac': {'M_IL17A_response': ['Il1b', 'Il12a', 'Ifng', 'Cxcl3', 'Ccl3', 'Csf2', 'Il9', 'Il12b'], 'M_mac_CSF1_response': ['Pltp', 'Slc47a1', 'Vat1', 'Hadh', 'Pebp1', 'Scd', 'Slc38a6', 'Vsig4', 'Rragd', 'Zfyve26', 'Sqle', 'Acp5', 'Acat2', 'Cep55', 'Rgl1', 'Spp1', 'Itgb5', 'Idh1', 'Cyb5a', 'Dhcr7', 'Dhcr24', 'A2m', 'C3ar1', 'Enosf1', 'Nr1h3', 'Ptprm', 'Plpp3', 'Ctsk', 'Lgmn', 'Mgll', 'Lilrb5', 'Gnpda1', 'Jakmip2', 'Plxna1', 'Snx24', 'Npc1', 'Frmd4a', 'Dennd2d', 'Acot13', 'Tspan4', 'Slc7a8', 'Cd59', 'Aldh7a1', 'Apoe', 'C1qb', 'Ccl2', 'Nrp1', 'Etv5', 'Fuca1', 'Gpr137b', 'Optn', 'Colec12', 'Marco', 'Mapk13', 'Hsd17b14', 'Dram1', 'Rnase1', 'Rad51ap1', 'Maf', 'Melk', 'Tyms', 'Ctsl', 'Rab3il1', 'Plau', 'Apoc1', 'Bcat1', 'Hamp', 'Pla2g15', 'Msr1', 'Mmp9', 'Qprt', 'Pparg', 'Rarres1', 'Lima1', 'Dab2', 'Top2a', 'Slc39a8', 'Ecm1', 'Ccnd1', 'Slc2a5', 'Acp2', 'Fasn', 'Gpnmb', 'Epas1', 'Ms4a4a', 'Adamdec1', 'Npl', 'Hacd3'], 'M_angiogenic-effectors': ['Vegfc', 'Plau', 'Angpt2', 'Pdgfb', 'Jag2', 'Pf4',
# ...

# %%
import pandas as pd

# Add a new column 'celltype' to the .obs metadata
Mac.obs['celltype'] = 'Mac'

# Verify the new column
print(Mac.obs.head())
# Out:
#                                orig.ident  nCount_RNA  nFeature_RNA  \
# AAACCAATCTAAGTCTAGAGGCAA-1  SeuratProject      1917.0          1254
# AAGCGGCTCCGCACCAAGAGGCAA-1  SeuratProject       503.0           379
# AAGGGAGGTTAGCATCAGAGGCAA-1  SeuratProject       700.0           592
# AATGGATGTAAGGTTGAGAGGCAA-1  SeuratProject       556.0           446
# AATGGATGTAAGTCGAAGAGGCAA-1  SeuratProject       881.0           666
#
#                             percent.mt  percent.rb RNA_snn_res.0.1  \
# AAACCAATCTAAGTCTAGAGGCAA-1   10.328638         0.0               3
# AAGCGGCTCCGCACCAAGAGGCAA-1    0.994036         0.0               3
# AAGGGAGGTTAGCATCAGAGGCAA-1    0.285714         0.0               3
# AATGGATGTAAGGTTGAGAGGCAA-1    0.179856         0.0               3
# AATGGATGTAAGTCGAAGAGGCAA-1    0.227015         0.0               3
#
#                             seurat_clusters  pANN_0.25_0.17_480  \
# AAACCAATCTAAGTCTAGAGGCAA-1               11            0.329013
# ...

# %%
Spectra_dict_Mac = spc_tl.check_gene_set_dictionary(
    Mac,
    Spectra_dict_Mac,
    obs_key='celltype',
    global_key='global')
# Out:
# Cell type labels in gene set annotation dictionary and AnnData object are identical
# removing gene set M_IL17A_response for cell type Mac which is of length 8 1 genes are found in the data. minimum length is 3
# removing gene set all_retinol_metabolism for cell type global which is of length 20 2 genes are found in the data. minimum length is 3
# removing gene set all_propanoate_metabolism for cell type global which is of length 7 0 genes are found in the data. minimum length is 3
# removing gene set all_transmembrane-transport-ER for cell type global which is of length 3 1 genes are found in the data. minimum length is 3
# removing gene set all_complement_production for cell type global which is of length 18 2 genes are found in the data. minimum length is 3
# removing gene set all_creatinine_metabolism for cell type global which is of length 6 1 genes are found in the data. minimum length is 3
# ...

# %%
# Step 1: Identify highly variable genes
sc.pp.highly_variable_genes(Mac, flavor='seurat', n_top_genes=2000)

# %%
# fit the model (We will run this with only 2 epochs to decrease runtime in this tutorial)

Mac.X = Mac.X.toarray() if scipy.sparse.issparse(Mac.X) else Mac.X

model = spc.est_spectra(adata=Mac,
    gene_set_dictionary=Spectra_dict_Mac,
    use_highly_variable=True,
    cell_type_key="celltype",
    use_weights=True,
    lam=0.1, # varies depending on data and gene sets, try between 0.5 and 0.001
    delta=0.001,
    kappa=None,
    rho=0.001,
    use_cell_types=True,
    n_top_vals=50,
    label_factors=True,
    overlap_threshold=0.2,
    clean_gs = True,
    min_gs_num = 3,
    num_epochs=10000#here running only 2 epochs for time reasons, we recommend 10,000 epochs for most datasets
)
# Out:
# Cell type labels in gene set annotation dictionary and AnnData object are identical
# Your gene set annotation dictionary is now correctly formatted.
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████▉   | 9701/10000 [12:46<00:23, 12.65it/s]
# /Users/jyotirmoyroy/miniconda3/lib/python3.12/site-packages/Spectra/Spectra.py:1340: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Hs6st1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[i,j] = id2word[idx_matrix[i,j]]
# /Users/jyotirmoyroy/miniconda3/lib/python3.12/site-packages/Spectra/Spectra.py:1340: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Chsy1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
Mac
# Out:
# AnnData object with n_obs × n_vars = 1250 × 6225
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'percent.rb', 'RNA_snn_res.0.1', 'seurat_clusters', 'pANN_0.25_0.17_480', 'doublet_finder', 'sample', 'time', 'group', 'pANN_0.25_0.28_1286', 'pANN_0.25_0.27_74', 'pANN_0.25_0.21_789', 'pANN_0.25_0.3_2525', 'pANN_0.25_0.3_3206', 'pANN_0.25_0.3_1840', 'pANN_0.25_0.25_460', 'pANN_0.25_0.3_908', 'pANN_0.25_0.3_2082', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'SCT_snn_res.0.5', 'SCT_snn_res.0.4', 'CellSubType', 'celltype'
#     var: 'features', 'SCT_features', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'spectra_vocab'
#     uns: 'hvg', 'SPECTRA_factors', 'SPECTRA_markers', 'SPECTRA_L', 'SPECTRA_overlap'
#     obsm: 'X_umap', 'SPECTRA_cell_scores'
#     layers: 'SCT'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

factor_names = Mac.uns['SPECTRA_overlap'].index.tolist()
# Assuming `CD8TCells.obsm['SPECTRA_cell_scores']` contains the cell-factor scores
factor_scores_matrix = Mac.obsm['SPECTRA_cell_scores']  # Cell-factor score matrix (cells x factors)

# Step 2: Create a DataFrame with factor names as columns
factor_scores_df = pd.DataFrame(factor_scores_matrix, columns=factor_names)

# Step 3: Calculate the correlation matrix across factors
factor_correlation = factor_scores_df.corr()

# Set a threshold for correlation
threshold = 0.1  # Only show correlations with absolute value above this threshold
mask = (factor_correlation.abs() < threshold)  # Mask for values below absolute threshold

# Clip values to range -1 to 1 to limit color scale
factor_correlation = factor_correlation.clip(lower=-1, upper=1)

# Identify factors with significant correlations (above absolute threshold) excluding diagonal
significant_correlations = []
for i in range(factor_correlation.shape[0]):
    for j in range(i + 1, factor_correlation.shape[1]):
        if abs(factor_correlation.iloc[i, j]) >= threshold:
            significant_correlations.append((factor_correlation.index[i], factor_correlation.columns[j], factor_correlation.iloc[i, j]))

# Print the significant correlations
output_dir = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/"  # Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)
correlations_filename = os.path.join(output_dir, "Significant_correlations_Mac.csv")
correlations_df = pd.DataFrame(significant_correlations, columns=["Factor 1", "Factor 2", "Correlation"])
correlations_df.to_csv(correlations_filename, index=False)

print(f"Significant correlations saved to: {correlations_filename}")
# Out:
# Significant correlations saved to: /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Significant_correlations_Mac.csv

# %%
# Adjust figure size
plt.figure(figsize=(12, 10))

# Create heatmap with adjusted label rotation and font size
sns.heatmap(factor_correlation, cmap='RdBu', center=0, vmin=-1, vmax=1, mask=mask, square=True,
            cbar_kws={'label': 'Pearson correlation'}, xticklabels=factor_names, yticklabels=factor_names)

plt.title("Factor-Factor Correlation Heatmap (-1 to 1)", fontsize=14)

# Rotate x and y-axis labels for readability
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)

n = 2  # Show every 5th label
plt.xticks(ticks=range(0, len(factor_names), n), labels=[factor_names[i] for i in range(0, len(factor_names), n)], rotation=90, fontsize=8)
plt.yticks(ticks=range(0, len(factor_names), n), labels=[factor_names[i] for i in range(0, len(factor_names), n)], rotation=0, fontsize=8)

# Save the heatmap
heatmap_filename = os.path.join(output_dir, "factor_correlation_heatmap_Mac.png")
plt.savefig(heatmap_filename, format='png', dpi=300, bbox_inches='tight')

plt.show()

# %%
#Save the Mac file
import scanpy as sc
import os

# Define output file path
output_file = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Mac_T1DTimepoints_Spectra.h5ad"

# Save the AnnData object
Mac.write(output_file)

print(f"Mac object saved as: {output_file}")
# Out:
# Mac object saved as: /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Mac_T1DTimepoints_Spectra.h5ad

# %%
output_dir = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/"  # Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)
correlations_filename = os.path.join(output_dir, "Significant_correlations_Mac.csv")
correlations_df = pd.DataFrame(significant_correlations, columns=["Factor 1", "Factor 2", "Correlation"])
correlations_df.to_csv(correlations_filename, index=False)

print(f"Significant correlations saved to: {correlations_filename}")
# Out:
# Significant correlations saved to: /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Significant_correlations_Mac.csv

# %%
# Replace values in the 'group' column
Mac.obs['group'] = Mac.obs['group'].replace({0: 'Non-Progressor', 1: 'Progressor'})

# Verify the changes
print(Mac.obs[['sample', 'group']].drop_duplicates())
# Out:
#                               sample           group
# AAACCAATCTAAGTCTAGAGGCAA-1   Week6_1  Non-Progressor
# AACTAAGTCTTAAGCTACTACTCA-1   Week6_2      Progressor
# ACTAGTTTCAAGCGATATACGTCA-1   Week6_3  Non-Progressor
# AAACAAGCAACTAAACATCATGTG-1   Week6_4      Progressor
# AAACAAGCACAGCAACAACGCCGA-1   Week6_5      Progressor
# AAAGCATGTTGGATAGATTCGGTT-1   Week6_6  Non-Progressor
# AACCATAAGGCTTATTAAGTAGAG-1  Week12_1      Progressor
# AAATCGATCCTCCCACAGCTGTGA-1  Week12_2      Progressor
# ACGGATAGTTCACCAGACAGTCTG-1  Week12_3  Non-Progressor
# AACTTCGTCAATGGGTAGTGAGTG-1  Week12_4  Non-Progressor

# %%
#Aggregate Cell Scores by Sample
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Extract relevant data
spectra_scores = Mac.obsm['SPECTRA_cell_scores']  # Cell-factor score matrix
samples = Mac.obs['sample']  # Sample metadata
groups = Mac.obs['group']  # Replace group labels

# Convert to DataFrame
df_spectra = pd.DataFrame(spectra_scores, index=Mac.obs_names)  # Convert to DataFrame
df_spectra['sample'] = samples.values  # Add sample column
df_spectra['group'] = groups.values  # Add group column

# Aggregate scores per sample for Factor 65 (mean score per sample)
df_factor29 = df_spectra.groupby(['sample', 'group'], observed=True)[8].mean().reset_index()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statannotations.Annotator as Annotator

plt.figure(figsize=(8, 5))
sns.boxplot(x='group', y=8, data=df_factor29, width=0.5, fliersize=0, palette={"Non-Progressor": "blue", "Progressor": "red"})
sns.stripplot(x='group', y=8, data=df_factor29, color='black', alpha=0.6, size=8, jitter=True)

# Customize plot
plt.xlabel("")
plt.ylabel("Factor 29 SPECTRA Score (Type-II-ifn-response)")
plt.title("SPECTRA Factor 8 Score by Group")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /var/folders/d1/fs384x7167s82230j50t6nc00000gn/T/ipykernel_95543/2766640309.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='group', y=8, data=df_factor29, width=0.5, fliersize=0, palette={"Non-Progressor": "blue", "Progressor": "red"})

# %%
pip install statannotations
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statannotations.Annotator as Annotator
from statsmodels.stats.multitest import multipletests

# %%
df_spectra
# Out:
#                                        0             1             2  \
# AAACCAATCTAAGTCTAGAGGCAA-1  2.101896e-12  4.017437e-04  1.571197e-03
# AAGCGGCTCCGCACCAAGAGGCAA-1  8.419596e-12  4.727006e-10  1.126350e-07
# AAGGGAGGTTAGCATCAGAGGCAA-1  2.832675e-12  2.000603e-04  1.332818e-07
# AATGGATGTAAGGTTGAGAGGCAA-1  9.205445e-12  3.258964e-04  4.116031e-04
# AATGGATGTAAGTCGAAGAGGCAA-1  2.389437e-11  2.086508e-11  7.628242e-04
# ...                                  ...           ...           ...
# TGTCAGGAGCTTCCTTAGTGAGTG-1  4.714783e-12  1.645867e-11  1.664523e-10
# TTACCTTGTTTACTGAAGTGAGTG-1  3.273381e-12  3.368145e-11  1.120171e-03
# TTGTGATTCCAACTTGAGTGAGTG-1  2.137139e-12  2.280713e-12  2.154151e-10
# TTGTTGTAGCAAGACTAGTGAGTG-1  3.092650e-12  2.064254e-11  1.144219e-03
# TTTGCTCTCACAGCCTAGTGAGTG-1  1.892072e-12  5.984305e-04  3.824657e-04
#
#                                        3             4             5  \
# ...

# %%
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests

# Extract relevant data
spectra_scores = Mac.obsm['SPECTRA_cell_scores']  # Cell-factor score matrix
samples = Mac.obs['sample']  # Sample metadata
groups = Mac.obs['group']  # Group labels

# Convert to DataFrame
df_spectra = pd.DataFrame(spectra_scores, index=Mac.obs_names)
df_spectra['sample'] = samples.values
df_spectra['group'] = groups.values

# Aggregate cell scores per sample (mean across all cells per sample)
df_aggregated = df_spectra.groupby(['sample', 'group'], observed=True).mean().reset_index()


# Prepare list to store results
results = []

# Iterate through each factor (excluding 'sample' and 'group' columns)
for factor in df_aggregated.columns[2:]:  
    # Extract sample-level aggregated scores for each group
    group1 = df_aggregated[df_aggregated['group'] == 'Non-Progressor'][factor]
    group2 = df_aggregated[df_aggregated['group'] == 'Progressor'][factor]
    
    # Perform Mann-Whitney U-test
    stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    
    # Compute fold change (Progressor / Non-Progressor mean)
    mean_group1 = group1.mean()
    mean_group2 = group2.mean()
    fc = mean_group2 / mean_group1 if mean_group1 != 0 else None  # Avoid division by zero
    
    # Append results
    results.append({
        'Factor': factor,
        'p_value': p_value,
        'fold_change': fc
    })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Adjust p-values using Benjamini-Hochberg (FDR correction)
results_df['FDR'] = multipletests(results_df['p_value'], method='fdr_bh')[1]

# Filter significant factors (FDR < 0.05)
#significant_factors = results_df[results_df['p_value'] < 0.1]

# Save results to CSV
results_df.to_csv('/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/MacrophageMac_T1D_Timepoints_Factors_pvalue_FC.csv', index=False)

print("Significant factors saved to 'Significant_factors_Mac_pvalue_filter.csv'")
# Out:
# Significant factors saved to 'Significant_factors_Mac_pvalue_filter.csv'

# %%
df_spectra.to_csv("/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq//Spectra/T1D_Timepoints/Macrophage/Mac_T1D_Timepoints_CellScores.csv", index=False)

# %%
# Extract row names corresponding to factor names
row_names = factor_correlation.index.to_frame(index=False)

# Save as CSV
row_names.to_csv("/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq//Spectra/T1D_Timepoints/Macrophage/factor_correlation_rownames_Mac_T1D_Timepoints.csv", index=False, header=False)

print("Factor_correlation_names_Mac_T1D_Timepoints.csv")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Factor_correlation_names_Mac_T1D_Timepoints.csv

# %%
Mac.obs['time']
# Out:
# AAACCAATCTAAGTCTAGAGGCAA-1     Week6
# AAGCGGCTCCGCACCAAGAGGCAA-1     Week6
# AAGGGAGGTTAGCATCAGAGGCAA-1     Week6
# AATGGATGTAAGGTTGAGAGGCAA-1     Week6
# AATGGATGTAAGTCGAAGAGGCAA-1     Week6
#                                ...
# TGTCAGGAGCTTCCTTAGTGAGTG-1    Week12
# TTACCTTGTTTACTGAAGTGAGTG-1    Week12
# TTGTGATTCCAACTTGAGTGAGTG-1    Week12
# TTGTTGTAGCAAGACTAGTGAGTG-1    Week12
# TTTGCTCTCACAGCCTAGTGAGTG-1    Week12
# Name: time, Length: 1250, dtype: category
# Categories (2, object): ['Week6', 'Week12']

# %%
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests

# Extract relevant data
spectra_scores = Mac.obsm['SPECTRA_cell_scores']  # Cell-factor score matrix
samples = Mac.obs['sample']  # Sample metadata
groups = Mac.obs['group']  # Group labels
timepoints = Mac.obs['time']  # Add timepoint metadata

# Convert to DataFrame
df_spectra = pd.DataFrame(spectra_scores, index=Mac.obs_names)
df_spectra['sample'] = samples.values
df_spectra['group'] = groups.values
df_spectra['time'] = timepoints.values

# Select only Week6 data
df_spectra_week6 = df_spectra[df_spectra['time'] == 'Week6'].drop(columns=['time'])

# Aggregate cell scores per sample (mean across all cells per sample)
df_aggregated = df_spectra_week6.groupby(['sample', 'group'], observed=True).mean().reset_index()

# Prepare list to store results
results = []

# Iterate through each factor (excluding 'sample', 'group', and 'time' columns)
for factor in df_aggregated.columns[2:]:  
    # Extract sample-level aggregated scores for each group
    group1 = df_aggregated[df_aggregated['group'] == 'Non-Progressor'][factor]
    group2 = df_aggregated[df_aggregated['group'] == 'Progressor'][factor]
    
    # Perform Mann-Whitney U-test
    stat, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')
    
    # Compute fold change (Progressor / Non-Progressor mean)
    mean_group1 = group1.mean()
    mean_group2 = group2.mean()
    fc = mean_group2 / mean_group1 if mean_group1 != 0 else None  # Avoid division by zero
    
    # Append results
    results.append({
        'Factor': factor,
        'p_value': p_value,
        'fold_change': fc
    })

# Convert results to DataFrame
results_df_w6 = pd.DataFrame(results)

# Adjust p-values using Benjamini-Hochberg (FDR correction)
results_df_w6['FDR'] = multipletests(results_df['p_value'], method='fdr_bh')[1]

# Save results to CSV
output_path = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/Mac_Week6_Factors_pvalue_FC.csv"
results_df_w6.to_csv(output_path, index=False)

print(f"Results saved to {output_path}")
# Out:
# Results saved to /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/Mac_Week6_Factors_pvalue_FC.csv

# %%
results_df_w6
# Out:
#      Factor  p_value  fold_change  FDR
# 0         0      0.4     1.289034  1.0
# 1         1      1.0     0.952294  1.0
# 2         2      0.7     0.940205  1.0
# 3         3      1.0     1.015729  1.0
# 4         4      1.0     0.980327  1.0
# ..      ...      ...          ...  ...
# 134     134      0.4     1.157168  1.0
# 135     135      0.7     1.538599  1.0
# 136     136      0.4     0.796902  1.0
# 137     137      0.7     1.169152  1.0
# 138     138      0.7     0.933758  1.0
#
# [139 rows x 4 columns]

# %%
# Aggregate cell scores per sample (mean across all cells per sample)
df_aggregated = df_spectra_week6.groupby(['sample', 'group'], observed=True)

# %%
df_aggregated

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from datetime import datetime

# Step 1: Subset macrophage data for Week6 and drop 'time' column
Week6_Mac_data = Mac[Mac.obs['time'] == 'Week6'].copy()
Week6_Mac_data.obs.drop(columns=['time'], inplace=True)

# Step 2: Extract factor names
Week6_Mac_factor_names = Week6_Mac_data.uns['SPECTRA_overlap'].index.tolist()

# Step 3: Retrieve factor scores (cells x factors)
Week6_Mac_factor_scores = Week6_Mac_data.obsm['SPECTRA_cell_scores']

# Step 4: Convert to DataFrame
Week6_Mac_factor_df = pd.DataFrame(Week6_Mac_factor_scores, columns=Week6_Mac_factor_names)

# Step 5: Compute correlation matrix
Week6_Mac_correlation_matrix = Week6_Mac_factor_df.corr()

# Step 6: Set correlation threshold
correlation_threshold = 0.1
mask_below_threshold = Week6_Mac_correlation_matrix.abs() < correlation_threshold

# Step 7: Clip values to range -1 to 1
Week6_Mac_correlation_matrix = Week6_Mac_correlation_matrix.clip(lower=-1, upper=1)

# Step 8: Extract significant correlations
Week6_Mac_significant_correlations = [
    (Week6_Mac_correlation_matrix.index[i], Week6_Mac_correlation_matrix.columns[j], Week6_Mac_correlation_matrix.iloc[i, j])
    for i in range(Week6_Mac_correlation_matrix.shape[0])
    for j in range(i + 1, Week6_Mac_correlation_matrix.shape[1])
    if abs(Week6_Mac_correlation_matrix.iloc[i, j]) >= correlation_threshold
]

# Step 9: Define output directory and ensure it exists

Week6_Mac_correlations_df = pd.DataFrame(Week6_Mac_significant_correlations, columns=["Factor_A", "Factor_B", "Correlation"])
Week6_Mac_correlations_df.to_csv("/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/Significant_correlations_Mac_Week6.csv", index=False)

print(f"Significant correlations for Week6 Mac saved to: {output_filepath}")
# Out:
# Significant correlations for Week6 Mac saved to: /Users/jyotirmoyroy/Desktop/Immunometabolism_T1D_Paper/Data/Sequencing/SingleCellRNASeq/Significant_Correlations_Week6_Mac_20250219_144953.csv

# %%
output_filepath
# Out:
# '/Users/jyotirmoyroy/Desktop/Immunometabolism_T1D_Paper/Data/Sequencing/SingleCellRNASeq/Significant_Correlations_Week6_Mac_20250219_144953.csv'

# %%
Week6_Mac_correlations_df
# Out:
#                                                Factor_A  \
# 0     0-X-global-X-all_chondroitine-and-heparan-sulf...
# 1     0-X-global-X-all_chondroitine-and-heparan-sulf...
# 2     0-X-global-X-all_chondroitine-and-heparan-sulf...
# 3     0-X-global-X-all_chondroitine-and-heparan-sulf...
# 4     0-X-global-X-all_chondroitine-and-heparan-sulf...
# ...                                                 ...
# 1142                                 135-X-global-X-135
# 1143                                 135-X-global-X-135
# 1144                                 135-X-global-X-135
# 1145           136-X-global-X-all_hyaluronan_metabolism
# 1146           136-X-global-X-all_hyaluronan_metabolism
#
#                                             Factor_B  Correlation
# 0                     2-X-global-X-all_p53-signaling     0.103648
# 1                  4-X-global-X-all_circadian-rhythm     0.105826
# 2          13-X-global-X-all_iron-uptake-and-storage     0.105914
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from datetime import datetime
import numpy as np

# Step 1: Subset macrophage data for Week6
Week6_Mac = Mac[Mac.obs['time'] == 'Week6'].copy()

# Step 2: Extract factor names
factor_names = Week6_Mac.uns['SPECTRA_overlap'].index.tolist()

# Step 3: Retrieve factor scores (cells x factors)
factor_scores = Week6_Mac.obsm['SPECTRA_cell_scores']

# Step 4: Convert to DataFrame
factor_df = pd.DataFrame(factor_scores, columns=factor_names)

# Step 5: Compute correlation matrix
correlation_matrix = factor_df.corr()

# Step 6: Set correlation thresholds
high_corr_threshold = 0.5
low_corr_threshold = -0.4

# Step 7: Find pairs of factors that meet the threshold
significant_pairs = np.where((correlation_matrix > high_corr_threshold) | (correlation_matrix < low_corr_threshold))

# Step 8: Extract unique factor names from the significant pairs
significant_factors = set(correlation_matrix.columns[significant_pairs[0]]).union(set(correlation_matrix.columns[significant_pairs[1]]))

# Convert the set to a list for indexing
significant_factors = list(significant_factors)

# Step 9: Filter the correlation matrix to include only significant factors
filtered_correlation_matrix = correlation_matrix.loc[significant_factors, significant_factors]

# Step 10: Define output directory
output_directory = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/"
os.makedirs(output_directory, exist_ok=True)

# Step 11: Generate unique filename
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
heatmap_filename = os.path.join(output_directory, f"factor_correlation_heatmap_Week6_Mac.png")

# Step 12: Plot only significant factors
plt.figure(figsize=(12, 10))
sns.heatmap(filtered_correlation_matrix, cmap='RdBu_r', center=0, vmin=-1, vmax=1, square=True,
            cbar_kws={'label': 'Pearson correlation'}, xticklabels=False, yticklabels=False)

plt.title("Significant Factor-Factor Correlation Heatmap (Week6 Mac)", fontsize=14)

# Adjust label readability
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)

# Save the heatmap
plt.savefig(heatmap_filename, format='png', dpi=300, bbox_inches='tight')

plt.show()

print(f"Heatmap saved to: {heatmap_filename}")
# Out:
# Heatmap saved to: /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/factor_correlation_heatmap_Week6_Mac.png

# %%
print(filtered_correlation_matrix.shape)
# Out:
# (139, 139)

# %%
filtered_correlation_matrix
# Out:
#                                                 48-X-global-X-48  \
# 48-X-global-X-48                                        1.000000
# 73-X-global-X-all_MYC_targets                           0.045626
# 93-X-global-X-all_MHC-I-presentation                   -0.051422
# 41-X-global-X-all_autophagy-peroxisome                 -0.058561
# 38-X-global-X-all_nucleotide_metabolism                -0.095473
# ...                                                          ...
# 86-X-global-X-all_phosphoinositide_signaling            0.003334
# 14-X-global-X-all_n-glycan_synthesis                   -0.062194
# 60-X-global-X-all_pentose-phosphate-pathway             0.015075
# 77-X-global-X-all_fatty-acid-metabolism                 0.111763
# 118-X-global-X-all_glycerin-SER-THR_metabolism         -0.165651
#
#                                                 73-X-global-X-all_MYC_targets  \
# 48-X-global-X-48                                                     0.045626
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from datetime import datetime

# Step 1: Subset macrophage data for Week6
Week6_Mac = Mac[Mac.obs['time'] == 'Week6'].copy()

# Step 2: Define the specific factor names
factor_names = [
    "10-X-global-X-all_SASP",
    "12-X-global-X-all_TNF-via-NFkB_signaling",
    "26-X-global-X-all_glycogenesis",
    "29-X-global-X-all_type-II-ifn-response",
    "37-X-global-X-all_actin-cytoskeleton_regulation",
    "40-X-global-X-all_type-I-ifn-response",
    "56-X-global-X-all_DNA-methylation",
    "60-X-global-X-all_pentose-phosphate-pathway",
    "89-X-global-X-all_keratan-sulfate_degradation",
    "104-X-global-X-all_HIS_metabolism",
    "126-X-global-X-all_eicosanoid_metabolism",
    "133-X-global-X-Mac_IL4-IL13_response",
    "136-X-global-X-all_hyaluronan_metabolism",
    "33-X-global-X-all_hypoxia-response",
    "119-X-global-X-all_carnitine-shuttle",
    "93-X-global-X-all_MHC-I-presentation",
    "96-X-global-X-all_lipophagy"
]

# Step 3: Retrieve factor scores (cells x factors) for the specified factors
factor_scores = Week6_Mac.obsm['SPECTRA_cell_scores']
factor_df = pd.DataFrame(factor_scores, columns=Week6_Mac.uns['SPECTRA_overlap'].index.tolist())

# Step 4: Subset the factor_df to include only the specified factors
factor_df = factor_df[factor_names]

# Step 5: Compute correlation matrix
correlation_matrix = factor_df.corr()

# Step 6: Define output directory
output_directory = "/Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/"
os.makedirs(output_directory, exist_ok=True)

# Step 7: Generate unique filename
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
heatmap_filename = os.path.join(output_directory, f"factor_correlation_heatmap_Week6_Mac_selectedpathways.png")

# Step 8: Plot the correlation matrix
plt.figure(figsize=(12, 10))
ax = sns.heatmap(correlation_matrix, cmap='RdBu_r', center=0, vmin=-1, vmax=1, square=True,
            cbar_kws={'label': 'Pearson correlation'}, yticklabels=correlation_matrix.index, xticklabels=False)

plt.title("Factor-Factor Correlation- Macrophage (Early)", fontsize=18)  # Increased title font size

# Adjust label readability
plt.xticks(fontsize=20)  # Hide x-axis labels
plt.yticks(fontsize=20)  # Increase y-axis label font size

# Adjust colorbar label size
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=16)  # Make colorbar labels larger
cbar.set_label("Pearson Correlation", fontsize=14, fontweight='bold')  # Make legend label larger


# Save the heatmap
plt.savefig(heatmap_filename, format='png', dpi=300, bbox_inches='tight')

plt.show()

print(f"Heatmap saved to: {heatmap_filename}")
# Out:
# Heatmap saved to: /Users/jyotirmoyroy/Desktop/Immunometabolism T1D Paper/Data/Sequencing/SingleCellRNASeq/Spectra/T1D_Timepoints/Macrophage/factor_correlation_heatmap_Week6_Mac_selectedpathways.png
